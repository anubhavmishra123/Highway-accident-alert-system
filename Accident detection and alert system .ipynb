# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import SGD, Adam, Adagrad, Adadelta, RMSprop
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.models import model_from_json
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import sklearn.metrics as metrics
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import scipy.misc
import os 
import glob
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import zipfile
import csv
import seaborn as sns
from time import time

# %%
IMG_CATEGORIES = {0: 'Accident', 1: ' '}

# %%
from keras.models import load_model
model = load_model("resnet-cnn-model.h5")

# %%
import cv2
def pred_img(img_path):
  IMG_SIZE = 224
  img = load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE), interpolation='nearest')
  prediction = model.predict(np.expand_dims(img, axis=0))
  result = np.argmax(prediction, axis=1)
  result = IMG_CATEGORIES.get(int(result))
  img = cv2.imread(img_path)
  cv2_imshow(img)
  print("Model's prediction:", result)

# %%
import requests
from datetime import datetime
import pytz

# %%
cap = cv2.VideoCapture("vid-20210603194056_N10S5kgr_L24h.mp4")

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')

# %%
out = cv2.VideoWriter("output23.avi",fourcc, 20.0,(int(cap.get(3)),int(cap.get(4))))

# %%
count = 0
i=0
font = cv2.FONT_HERSHEY_SIMPLEX

if (cap.isOpened()== False): 
    print("Error opening video stream or file")
while(cap.isOpened()):
   # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        
        img = cv2.resize(frame,(224,224)) 
        img = img.reshape(1,224,224,3)
        prediction = model.predict(img)
        result = np.argmax(prediction, axis=1)
        #print(prediction)
        result = IMG_CATEGORIES.get(int(result))
        cv2.putText(frame,result,(20,50), font, 1.5,(0,0,255),2,cv2.LINE_AA)
        out.write(frame)
        cv2.imshow('Video prediction 2', frame)
        if(count == 0):
            if(result == 'Accident'):
                IST = pytz.timezone('Asia/Kolkata')
                datetime_ist = datetime.now(IST)
                time_st = datetime_ist.strftime('%H:%M:%S')
                now = datetime.now()
                dt_string = now.strftime("%d/%m/%Y")
                message = "An accident has occured at Ashok nagar, Chennai on " + dt_string + " at " + time_st
                print(message)
                count = 1
                url = "https://www.fast2sms.com/dev/bulk"
                payload = "sender_id=FSTSMS&message="+ message +"&language=english&route=p&numbers=9685382077"
                headers = {
                'authorization': "61Mxn9mHDhVSXiwZWUF3Tul8EPrdtjaygfkqo72QANJB5bGRYeuixqtNpPecJ3nOlz9UD12jVa8sIQGE",
                'Content-Type': "application/x-www-form-urlencoded",
                'Cache-Control': "no-cache",
                }
                response = requests.request("POST", url, data=payload, headers=headers)
                print(response.text)
                
        # Press Q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

    # Break the loop
    else: 
        break
    i += 1
 

cap.release()
out.release()
# Closes all the frames
cv2.destroyAllWindows()
# Out:
# An accident has occured at Ashok nagar, Chennai on 06/06/2021 at 08:14:26
# {"return":true,"request_id":"k6fw71dasi2hnqt","message":["SMS sent successfully."]}

# %%
cap = cv2.VideoCapture("beamngdrive-cctv-crashes-3-vgrnkbdu-2qgj_cU64MpQI_vFpF.mp4")
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter("output23.avi",fourcc, 20.0,(int(cap.get(3)),int(cap.get(4))))
count = 0
i=0
font = cv2.FONT_HERSHEY_SIMPLEX

if (cap.isOpened()== False): 
    print("Error opening video stream or file")
while(cap.isOpened()):
   # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        
        img = cv2.resize(frame,(224,224)) 
        img = img.reshape(1,224,224,3)
        prediction = model.predict(img)
        result = np.argmax(prediction, axis=1)
        #print(prediction)
        result = IMG_CATEGORIES.get(int(result))
        cv2.putText(frame,result,(20,50), font, 1.5,(0,0,255),2,cv2.LINE_AA)
        out.write(frame)
        cv2.imshow('Video prediction 2', frame)
        if(count == 0):
            if(result == 'Accident'):
                IST = pytz.timezone('Asia/Kolkata')
                datetime_ist = datetime.now(IST)
                time_st = datetime_ist.strftime('%H:%M:%S')
                now = datetime.now()
                dt_string = now.strftime("%d/%m/%Y")
                message = "An accident has occured at Ashok nagar, Chennai on " + dt_string + " at " + time_st
                print(message)
                count = 1
                url = "https://www.fast2sms.com/dev/bulk"
                payload = "sender_id=FSTSMS&message="+ message +"&language=english&route=p&numbers=9685382077"
                headers = {
                'authorization': "61Mxn9mHDhVSXiwZWUF3Tul8EPrdtjaygfkqo72QANJB5bGRYeuixqtNpPecJ3nOlz9UD12jVa8sIQGE",
                'Content-Type': "application/x-www-form-urlencoded",
                'Cache-Control': "no-cache",
                }
                response = requests.request("POST", url, data=payload, headers=headers)
                print(response.text)
                
        # Press Q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

    # Break the loop
    else: 
        break
    i += 1
 

cap.release()
out.release()
# Closes all the frames
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture("cctv-traffic-intersection-realistic-crashes-15-beamng-drive-tot0sr3w-t3tk-hu8nyh_TJesoum2_aU5S.mp4")
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter("output23.avi",fourcc, 20.0,(int(cap.get(3)),int(cap.get(4))))
count = 0
i=0
font = cv2.FONT_HERSHEY_SIMPLEX

if (cap.isOpened()== False): 
    print("Error opening video stream or file")
while(cap.isOpened()):
   # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        
        img = cv2.resize(frame,(224,224)) 
        img = img.reshape(1,224,224,3)
        prediction = model.predict(img)
        result = np.argmax(prediction, axis=1)
        #print(prediction)
        result = IMG_CATEGORIES.get(int(result))
        cv2.putText(frame,result,(20,50), font, 1.5,(0,0,255),2,cv2.LINE_AA)
        out.write(frame)
        cv2.imshow('Video prediction 2', frame)
        if(count == 0):
            if(result == 'Accident'):
                IST = pytz.timezone('Asia/Kolkata')
                datetime_ist = datetime.now(IST)
                time_st = datetime_ist.strftime('%H:%M:%S')
                now = datetime.now()
                dt_string = now.strftime("%d/%m/%Y")
                message = "An accident has occured at Ashok nagar, Chennai on " + dt_string + " at " + time_st
                print(message)
                count = 1
                url = "https://www.fast2sms.com/dev/bulk"
                payload = "sender_id=FSTSMS&message="+ message +"&language=english&route=p&numbers=9685382077"
                headers = {
                'authorization': "61Mxn9mHDhVSXiwZWUF3Tul8EPrdtjaygfkqo72QANJB5bGRYeuixqtNpPecJ3nOlz9UD12jVa8sIQGE",
                'Content-Type': "application/x-www-form-urlencoded",
                'Cache-Control': "no-cache",
                }
                response = requests.request("POST", url, data=payload, headers=headers)
                print(response.text)
                
        # Press Q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

    # Break the loop
    else: 
        break
    i += 1
 

cap.release()
out.release()
# Closes all the frames
cv2.destroyAllWindows()
# Out:
# An accident has occured at Ashok nagar, Chennai on 06/06/2021 at 08:15:57
# {"return":true,"request_id":"xr1l9ubvc632m8q","message":["SMS sent successfully."]}

# %%
cap = cv2.VideoCapture("cctv-crashes-18-beamng-drive-nr3acj7q-q1w2_v0vqXmQ9_984P.mp4")
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter("output23.avi",fourcc, 20.0,(int(cap.get(3)),int(cap.get(4))))
count = 0
i=0
font = cv2.FONT_HERSHEY_SIMPLEX

if (cap.isOpened()== False): 
    print("Error opening video stream or file")
while(cap.isOpened()):
   # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        
        img = cv2.resize(frame,(224,224)) 
        img = img.reshape(1,224,224,3)
        prediction = model.predict(img)
        result = np.argmax(prediction, axis=1)
        #print(prediction)
        result = IMG_CATEGORIES.get(int(result))
        cv2.putText(frame,result,(20,50), font, 1.5,(0,0,255),2,cv2.LINE_AA)
        out.write(frame)
        cv2.imshow('Video prediction 2', frame)
        if(count == 0):
            if(result == 'Accident'):
                IST = pytz.timezone('Asia/Kolkata')
                datetime_ist = datetime.now(IST)
                time_st = datetime_ist.strftime('%H:%M:%S')
                now = datetime.now()
                dt_string = now.strftime("%d/%m/%Y")
                message = "An accident has occured at Ashok nagar, Chennai on " + dt_string + " at " + time_st
                print(message)
                count = 1
                url = "https://www.fast2sms.com/dev/bulk"
                payload = "sender_id=FSTSMS&message="+ message +"&language=english&route=p&numbers=9685382077"
                headers = {
                'authorization': "61Mxn9mHDhVSXiwZWUF3Tul8EPrdtjaygfkqo72QANJB5bGRYeuixqtNpPecJ3nOlz9UD12jVa8sIQGE",
                'Content-Type': "application/x-www-form-urlencoded",
                'Cache-Control': "no-cache",
                }
                response = requests.request("POST", url, data=payload, headers=headers)
                print(response.text)
                
        # Press Q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

    # Break the loop
    else: 
        break
    i += 1
 

cap.release()
out.release()
# Closes all the frames
cv2.destroyAllWindows()
# Out:
# An accident has occured at Ashok nagar, Chennai on 06/06/2021 at 08:20:31
# {"return":true,"request_id":"cka1qg29wt07ljp","message":["SMS sent successfully."]}

# %%
cap = cv2.VideoCapture("test4.mp4")

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')

# %%
out = cv2.VideoWriter("output23.avi",fourcc, 20.0,(int(cap.get(3)),int(cap.get(4))))

# %%
count = 0
i=0
font = cv2.FONT_HERSHEY_SIMPLEX

if (cap.isOpened()== False): 
    print("Error opening video stream or file")
while(cap.isOpened()):
   # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        
        img = cv2.resize(frame,(224,224)) 
        img = img.reshape(1,224,224,3)
        prediction = model.predict(img)
        result = np.argmax(prediction, axis=1)
        result = IMG_CATEGORIES.get(int(result))
        cv2.putText(frame,result,(20,50), font, 1.5,(0,0,255),2,cv2.LINE_AA)
        out.write(frame)
        cv2.imshow('Video prediction 2', frame)
        if(count == 0):
            if(result == 'Accident'):
                IST = pytz.timezone('Asia/Kolkata')
                datetime_ist = datetime.now(IST)
                time_st = datetime_ist.strftime('%H:%M:%S')
                now = datetime.now()
                dt_string = now.strftime("%d/%m/%Y")
                message = "An accident has occured at Ashok nagar, Chennai on " + dt_string + " at " + time_st
                print(message)
                count = 1
                url = "https://www.fast2sms.com/dev/bulk"
                payload = "sender_id=FSTSMS&message="+ message +"&language=english&route=p&numbers=9685382077"
                headers = {
                'authorization': "61Mxn9mHDhVSXiwZWUF3Tul8EPrdtjaygfkqo72QANJB5bGRYeuixqtNpPecJ3nOlz9UD12jVa8sIQGE",
                'Content-Type': "application/x-www-form-urlencoded",
                'Cache-Control': "no-cache",
                }
                response = requests.request("POST", url, data=payload, headers=headers)
                print(response.text)
        # Press Q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

    # Break the loop
    else: 
        break
    i += 1
 

cap.release()
out.release()
# Closes all the frames
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture("test1.mp4")

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')

# %%
out = cv2.VideoWriter("output23.avi",fourcc, 20.0,(int(cap.get(3)),int(cap.get(4))))

# %%
count = 0
i=0
font = cv2.FONT_HERSHEY_SIMPLEX

if (cap.isOpened()== False): 
    print("Error opening video stream or file")
while(cap.isOpened()):
   # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        
        img = cv2.resize(frame,(224,224)) 
        img = img.reshape(1,224,224,3)
        prediction = model.predict(img)
        result = np.argmax(prediction, axis=1)
        result = IMG_CATEGORIES.get(int(result))
        cv2.putText(frame,result,(20,50), font, 1.5,(0,0,255),2,cv2.LINE_AA)
        out.write(frame)
        cv2.imshow('Video prediction 2', frame)
        if(count == 0):
            if(result == 'Accident'):
                IST = pytz.timezone('Asia/Kolkata')
                datetime_ist = datetime.now(IST)
                time_st = datetime_ist.strftime('%H:%M:%S')
                now = datetime.now()
                dt_string = now.strftime("%d/%m/%Y")
                message = "An accident has occured at Ashok nagar, Chennai on " + dt_string + " at " + time_st
                print(message)
                count = 1
                url = "https://www.fast2sms.com/dev/bulk"
                payload = "sender_id=FSTSMS&message="+ message +"&language=english&route=p&numbers=9685382077"
                headers = {
                'authorization': "61Mxn9mHDhVSXiwZWUF3Tul8EPrdtjaygfkqo72QANJB5bGRYeuixqtNpPecJ3nOlz9UD12jVa8sIQGE",
                'Content-Type': "application/x-www-form-urlencoded",
                'Cache-Control': "no-cache",
                }
                response = requests.request("POST", url, data=payload, headers=headers)
                print(response.text)
        # Press Q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

    # Break the loop
    else: 
        break
    i += 1
 

cap.release()
out.release()
# Closes all the frames
cv2.destroyAllWindows()
